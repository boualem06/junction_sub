# %%
title="Facture de consommation de l'Electricite et du Gaz"
date="2eme semestre 2020"

# %%
# !pip install pytesseract

# %%
from PIL import Image
from IPython.display import display

# Specify the path to your image file
image_path = r'D:\faact.png'  # Update this with the correct path

# Open the image using Pillow
image = Image.open(image_path)

# Display the image
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1240x1754>

# %%
import pytesseract
from PIL import Image

# Path to Tesseract executable (change this to your Tesseract installation path)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Function to extract text from an image using Tesseract OCR
def extract_text_from_image(image_path):
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)
    return text

# Example usage
image_path = r'D:\faact.png'
extracted_text = extract_text_from_image(image_path)

# Extracting total amount (example logic, you might need to customize it based on your bill format)
total_amount = None
for line in extracted_text.splitlines():
    if 'Total'  in line:
        # Extracting total amount assuming it appears in the same line as 'Total'
        total_amount = line.split('Total')[1].strip()
        strings_to_remove = ["a payer (en espéces) (DA)", "(tua) thee ttt Gavia!"]
        for substring in strings_to_remove:
            total_amount = total_amount.replace(substring, '')
    if ('Facture de ') in line :
        titl=line.split('Facture')[1].strip()
   # elif 'Période du' in line:
      #  objet = line.split('Période du')[1].strip()
    if ('date') in line :
        dat=line.split('date')[1].strip()

if(title):
    print(f'title is :{title}')
    
if total_amount:
    print(f'Total Amount: {total_amount}')

if(date):
    print(f'periode :{date}')
# Out:
# title is :Facture de consommation de l'Electricite et du Gaz
# Total Amount:  2000,24
# periode :2eme semestre 2020
